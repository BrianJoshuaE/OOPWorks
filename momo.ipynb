# %%
class momowallet:
    def __init__(self, owner_name, balance=0):
        self.owner_name = owner_name
        self._balance = balance

    @property
    def balance(self):
        return self._balance

samuel_wallet = momowallet("Samuel", 1000)
print(f"{samuel_wallet.owner_name}'s wallet balance is {samuel_wallet.balance}")
# Out:
# Samuel's wallet balance is 1000

# %%
class momowallet:
    def __init__(self, owner_name, balance=0):
        self.owner_name = owner_name
        self._balance = balance

    property
    def balance(self):
        return self._balance

samuel_wallet = momowallet("Samuel", 1000)
print(f"{samuel_wallet.owner_name}'s wallet balance is {samuel_wallet.balance}")
# Out:
# Samuel's wallet balance is <bound method momowallet.balance of <__main__.momowallet object at 0x00000239BA458AD0>>
